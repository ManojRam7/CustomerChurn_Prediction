# %%
# Welcome to your new project!
import pandas as pd

# %%
# !pip install kagglehub
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Data loading from kaggle api

# %%
import kagglehub
import shutil
import os

# Download latest version
path = kagglehub.dataset_download("muhammadshahidazeem/customer-churn-dataset")

print("Path to dataset files:", path)

# Define destination directory
destination_dir = "data/raw/"

# Create destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Move all files from the downloaded path to the destination directory
for filename in os.listdir(path):
    src_file = os.path.join(path, filename)
    dst_file = os.path.join(destination_dir, filename)
    shutil.move(src_file, dst_file)

print(f"Files moved to {destination_dir}")
# Out:
# Path to dataset files: /Users/manojrammopati/.cache/kagglehub/datasets/muhammadshahidazeem/customer-churn-dataset/versions/1
# Files moved to data/raw/

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
df = pd.read_csv('data/raw/train.csv')
df.head()
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  object
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  object
#  8   Contract Length    440832 non-null  object
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 40.4+ MB
# CustomerID           1
# Age                  1
# Gender               1
# Tenure               1
# ...

# %% [markdown]
# --------------------------------------------------------------------------
# ## EDA with sweetviz faile

# %% [markdown]
# import pandas as pd
# import sweetviz as sv
#
# df_train = pd.read_csv('data/raw/train.csv')
#
# # Optional visual EDA
# report = sv.analyze(df_train)
# report.show_html('eda_report.html')

# %% [markdown]
# pip install ydata-profiling

# %% [markdown]
# from ydata_profiling import ProfileReport
#
# df = pd.read_csv("data/raw/train.csv")
# profile = ProfileReport(df, title="Churn Data Profiling Report", explorative=True)
# profile.to_file("reports/eda_profile.html")
#
#
# ----------------------------------------------------------------

# %%
# Display the first few rows, info, description, and null values of the DataFrame
df.head()
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  object
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  object
#  8   Contract Length    440832 non-null  object
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 40.4+ MB
# CustomerID           1
# Age                  1
# Gender               1
# Tenure               1
# ...

# %%
# !pip install seaborn matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example for a numerical column
sns.histplot(df['Tenure'])
plt.show()

# Example for a categorical column
sns.countplot(x='Churn', data=df)
plt.show()

# %% [markdown]
# Data exploration

# %%
# Load data
df = pd.read_csv('data/raw/train.csv')
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (440833, 12)
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# ...

# %%
# Data info
df.info()

# Describe numerical features
df.describe()

# Check missing values
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  object
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  object
#  8   Contract Length    440832 non-null  object
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 40.4+ MB
# CustomerID           1
# Age                  1
# Gender               1
# Tenure               1
# ...

# %% [markdown]
# Data cleaning

# %%
# Drop duplicates
import numpy as np
df = df.drop_duplicates()

# Fill missing values (example: fill with median for numerical, mode for categorical)
for col in df.select_dtypes(include=np.number).columns:
    df[col] = df[col].fillna(df[col].median())

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna(df[col].mode()[0])

print("Missing values after cleaning:\n", df.isnull().sum())
# Out:
# Missing values after cleaning:
#  CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %% [markdown]
# #### univariate analysis

# %%
# Numerical features
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols].hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# Categorical features
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    plt.figure(figsize=(6,3))
    sns.countplot(x=col, data=df)
    plt.title(col)
    plt.show()

# %% [markdown]
# #### Bi-variate analysis

# %%
# Numerical vs Target
for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x='Churn', y=col, data=df)
    plt.title(f'{col} vs Churn')
    plt.show()

# Categorical vs Target
for col in cat_cols:
    if col != 'Churn':
        ct = pd.crosstab(df[col], df['Churn'], normalize='index')
        ct.plot(kind='bar', stacked=True, figsize=(6,3))
        plt.title(f'{col} vs Churn')
        plt.ylabel('Proportion')
        plt.show()

# %% [markdown]
# #### Correlation anlysis

# %%
corr = df[num_cols].corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.to_csv('data/processed/eda_cleaned.csv', index=False)

# %% [markdown]
# # -----------------------------------------
# # EDA SUMMARY

# %% [markdown]
# ## No of records

# %%
print("No of records:", df.shape[0])
# Out:
# No of records: 440833

# %% [markdown]
# ## Churn distribution

# %%
print("Churn distribution:\n", df['Churn'].value_counts())
sns.countplot(x='Churn', data=df)
plt.show()
# Out:
# Churn distribution:
#  Churn
# 1.0    250000
# 0.0    190833
# Name: count, dtype: int64

# %% [markdown]
# ## 3.Missing values

# %%
print("Missing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %% [markdown]
# ## 4. Key influencing features
# After training a model (e.g., Logistic Regression or Random Forest), use feature importance:

# %%
# For logistic regression
importance = pd.Series(model.coef_[0], index=X.columns).sort_values(ascending=False)
print("Key influencing features:\n", importance.head(10))

# For Random Forest
rf_importance = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
print("Key influencing features (RF):\n", rf_importance.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # For logistic regression
# ----> 2 importance = pd.Series(model.coef_[0], index=X.columns).sort_values(ascending=False)
#       3 print("Key influencing features:\n", importance.head(10))
#       5 # For Random Forest
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## 5. Outliers

# %%
for col in num_cols:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# ## 6. Imbalance: Yes/No

# %%
churn_counts = df['Churn'].value_counts(normalize=True)
imbalance = churn_counts.min() < 0.4  # Example threshold
print("Imbalance:", "Yes" if imbalance else "No")
print("Churn distribution:\n", churn_counts)
# Out:
# Imbalance: No
# Churn distribution:
#  Churn
# 1.0    0.567108
# 0.0    0.432892
# Name: proportion, dtype: float64

# %% [markdown]
# ## 7. Features to remove
# Remove features with too many missing values, low variance, or high correlation.

# %%
# Example: Remove columns with >50% missing values
to_remove = df.columns[df.isnull().mean() > 0.5].tolist()
print("Features to remove (missing values):", to_remove)

# Example: Remove columns with only one unique value
low_variance = [col for col in df.columns if df[col].nunique() == 1]
print("Features to remove (low variance):", low_variance)
# Out:
# Features to remove (missing values): []
# Features to remove (low variance): []

# %% [markdown]
# # ----------------------------------------------

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('data/processed/eda_cleaned.csv', index=False)
#
# NameError: name 'df' is not defined
